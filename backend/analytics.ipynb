# %%
import pandas as pd 
import numpy as numpy
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('data.csv')
data
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing              65.0            263.0
# 1     Afghanistan  2014  Developing              59.9            271.0
# 2     Afghanistan  2013  Developing              59.9            268.0
# 3     Afghanistan  2012  Developing              59.5            272.0
# 4     Afghanistan  2011  Developing              59.2            275.0
# ...           ...   ...         ...               ...              ...
# 2933     Zimbabwe  2004  Developing              44.3            723.0
# 2934     Zimbabwe  2003  Developing              44.5            715.0
# 2935     Zimbabwe  2002  Developing              44.8             73.0
# 2936     Zimbabwe  2001  Developing              45.3            686.0
# 2937     Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# ...

# %%
data["Status"] = data["Status"].map({"Developing":"0","Developed":"1"})
data
# Out:
#        Country  Year Status  Life expectancy   Adult Mortality  infant deaths  \
# 112  Australia  2015      1              82.8             59.0              1
# 113  Australia  2014      1              82.7              6.0              1
# 114  Australia  2013      1              82.5             61.0              1
# 115  Australia  2012      1              82.3             61.0              1
# 116  Australia  2011      1              82.0             63.0              1
# 117  Australia  2010      1              81.9             64.0              1
# 118  Australia  2009      1              81.7             66.0              1
# 119  Australia  2008      1              81.3             66.0              1
# 120  Australia  2007      1              81.3             66.0              1
# 121  Australia  2006      1              81.2             66.0              1
# 122  Australia  2005      1              81.0             67.0              1
# ...

# %%
data = data[data["Country"] == "Australia"]
data
# Out:
#        Country  Year Status  Life expectancy   Adult Mortality  infant deaths  \
# 112  Australia  2015      1              82.8             59.0              1
# 113  Australia  2014      1              82.7              6.0              1
# 114  Australia  2013      1              82.5             61.0              1
# 115  Australia  2012      1              82.3             61.0              1
# 116  Australia  2011      1              82.0             63.0              1
# 117  Australia  2010      1              81.9             64.0              1
# 118  Australia  2009      1              81.7             66.0              1
# 119  Australia  2008      1              81.3             66.0              1
# 120  Australia  2007      1              81.3             66.0              1
# 121  Australia  2006      1              81.2             66.0              1
# 122  Australia  2005      1              81.0             67.0              1
# ...

# %%
data.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles', 'BMI', 'under-five deaths', 'Polio', 'Total expenditure',
#        'Diphtheria', 'HIV/AIDS', 'GDP', 'Population', 'thinness  1-19 years',
#        'thinness 5-9 years', 'Income composition of resources', 'Schooling',
#        'Prev_Life_Expectancy'],
#       dtype='object')

# %%
dataAus = data[data['Country']== 'Australia']
dataAus
# Out:
#        Country  Year     Status  Life expectancy   Adult Mortality  \
# 112  Australia  2015  Developed              82.8             59.0
# 113  Australia  2014  Developed              82.7              6.0
# 114  Australia  2013  Developed              82.5             61.0
# 115  Australia  2012  Developed              82.3             61.0
# 116  Australia  2011  Developed              82.0             63.0
# 117  Australia  2010  Developed              81.9             64.0
# 118  Australia  2009  Developed              81.7             66.0
# 119  Australia  2008  Developed              81.3             66.0
# 120  Australia  2007  Developed              81.3             66.0
# 121  Australia  2006  Developed              81.2             66.0
# 122  Australia  2005  Developed              81.0             67.0
# 123  Australia  2004  Developed              86.0             69.0
# 124  Australia  2003  Developed              83.0             71.0
# ...

# %%
total_pop_2015 = data[data['Year'] == 2015]['Population'].sum()
print(total_pop_2015)
# Out:
# 1575831950.68
